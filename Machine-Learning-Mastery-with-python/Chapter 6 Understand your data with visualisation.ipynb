# %% [markdown]
# # UNIVARIATE PLOTS

# %%
# Histograms

# %%
from matplotlib import pyplot
from pandas import read_csv
filename = 'pima-indians-diabetes.data.csv'
names = ['preg','plas','pres','skin','test','mass','pedi','age','class']
data = read_csv(filename, names=names)
data.hist(figsize = (10,10))
pyplot.show()

# %%
# Density plots

# %%
data.plot(kind = 'density',subplots = True, layout = (3,3), sharex = False,figsize = (10,10))
pyplot.show()

# %%
# BOX AND WHISKER PLOT

# %%
data.plot(kind = 'box',subplots = True, layout = (3,3),sharex = False, sharey = False,figsize = (10,10))
# Out:
# preg        AxesSubplot(0.125,0.657941;0.227941x0.222059)
# plas     AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# pres     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# skin        AxesSubplot(0.125,0.391471;0.227941x0.222059)
# test     AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# mass     AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# pedi           AxesSubplot(0.125,0.125;0.227941x0.222059)
# age         AxesSubplot(0.398529,0.125;0.227941x0.222059)
# class       AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# # MULTIVARIATE PLOTS

# %%
# Correlation matrix

# %%
import numpy

# %%
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin = -1, vmax = 1)
fig.colorbar(cax)
# ticks = numpy.arange(0,9,1)
# ax.set_xticks(ticks)
# ax.set_yticks(ticks)
# ax.set_xticklabels(names)
# ax.set_yticklabels(names)
pyplot.show()

# %%
# Scatter plot matrix

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, figsize = (5,5))
# Out:
# array([[<AxesSubplot:xlabel='preg', ylabel='preg'>,
#         <AxesSubplot:xlabel='plas', ylabel='preg'>,
#         <AxesSubplot:xlabel='pres', ylabel='preg'>,
#         <AxesSubplot:xlabel='skin', ylabel='preg'>,
#         <AxesSubplot:xlabel='test', ylabel='preg'>,
#         <AxesSubplot:xlabel='mass', ylabel='preg'>,
#         <AxesSubplot:xlabel='pedi', ylabel='preg'>,
#         <AxesSubplot:xlabel='age', ylabel='preg'>,
#         <AxesSubplot:xlabel='class', ylabel='preg'>],
#        [<AxesSubplot:xlabel='preg', ylabel='plas'>,
#         <AxesSubplot:xlabel='plas', ylabel='plas'>,
#         <AxesSubplot:xlabel='pres', ylabel='plas'>,
#         <AxesSubplot:xlabel='skin', ylabel='plas'>,
#         <AxesSubplot:xlabel='test', ylabel='plas'>,
#         <AxesSubplot:xlabel='mass', ylabel='plas'>,
#         <AxesSubplot:xlabel='pedi', ylabel='plas'>,
#         <AxesSubplot:xlabel='age', ylabel='plas'>,
#         <AxesSubplot:xlabel='class', ylabel='plas'>],
#        [<AxesSubplot:xlabel='preg', ylabel='pres'>,
#         <AxesSubplot:xlabel='plas', ylabel='pres'>,
#         <AxesSubplot:xlabel='pres', ylabel='pres'>,
#         <AxesSubplot:xlabel='skin', ylabel='pres'>,
#         <AxesSubplot:xlabel='test', ylabel='pres'>,
#         <AxesSubplot:xlabel='mass', ylabel='pres'>,
#         <AxesSubplot:xlabel='pedi', ylabel='pres'>,
#         <AxesSubplot:xlabel='age', ylabel='pres'>,
#         <AxesSubplot:xlabel='class', ylabel='pres'>],
#        [<AxesSubplot:xlabel='preg', ylabel='skin'>,
#         <AxesSubplot:xlabel='plas', ylabel='skin'>,
#         <AxesSubplot:xlabel='pres', ylabel='skin'>,
#         <AxesSubplot:xlabel='skin', ylabel='skin'>,
#         <AxesSubplot:xlabel='test', ylabel='skin'>,
#         <AxesSubplot:xlabel='mass', ylabel='skin'>,
#         <AxesSubplot:xlabel='pedi', ylabel='skin'>,
#         <AxesSubplot:xlabel='age', ylabel='skin'>,
#         <AxesSubplot:xlabel='class', ylabel='skin'>],
#        [<AxesSubplot:xlabel='preg', ylabel='test'>,
#         <AxesSubplot:xlabel='plas', ylabel='test'>,
#         <AxesSubplot:xlabel='pres', ylabel='test'>,
#         <AxesSubplot:xlabel='skin', ylabel='test'>,
#         <AxesSubplot:xlabel='test', ylabel='test'>,
#         <AxesSubplot:xlabel='mass', ylabel='test'>,
#         <AxesSubplot:xlabel='pedi', ylabel='test'>,
#         <AxesSubplot:xlabel='age', ylabel='test'>,
#         <AxesSubplot:xlabel='class', ylabel='test'>],
#        [<AxesSubplot:xlabel='preg', ylabel='mass'>,
#         <AxesSubplot:xlabel='plas', ylabel='mass'>,
#         <AxesSubplot:xlabel='pres', ylabel='mass'>,
#         <AxesSubplot:xlabel='skin', ylabel='mass'>,
#         <AxesSubplot:xlabel='test', ylabel='mass'>,
#         <AxesSubplot:xlabel='mass', ylabel='mass'>,
#         <AxesSubplot:xlabel='pedi', ylabel='mass'>,
#         <AxesSubplot:xlabel='age', ylabel='mass'>,
#         <AxesSubplot:xlabel='class', ylabel='mass'>],
#        [<AxesSubplot:xlabel='preg', ylabel='pedi'>,
#         <AxesSubplot:xlabel='plas', ylabel='pedi'>,
#         <AxesSubplot:xlabel='pres', ylabel='pedi'>,
#         <AxesSubplot:xlabel='skin', ylabel='pedi'>,
#         <AxesSubplot:xlabel='test', ylabel='pedi'>,
#         <AxesSubplot:xlabel='mass', ylabel='pedi'>,
#         <AxesSubplot:xlabel='pedi', ylabel='pedi'>,
#         <AxesSubplot:xlabel='age', ylabel='pedi'>,
#         <AxesSubplot:xlabel='class', ylabel='pedi'>],
#        [<AxesSubplot:xlabel='preg', ylabel='age'>,
#         <AxesSubplot:xlabel='plas', ylabel='age'>,
#         <AxesSubplot:xlabel='pres', ylabel='age'>,
#         <AxesSubplot:xlabel='skin', ylabel='age'>,
#         <AxesSubplot:xlabel='test', ylabel='age'>,
#         <AxesSubplot:xlabel='mass', ylabel='age'>,
#         <AxesSubplot:xlabel='pedi', ylabel='age'>,
#         <AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='class', ylabel='age'>],
#        [<AxesSubplot:xlabel='preg', ylabel='class'>,
#         <AxesSubplot:xlabel='plas', ylabel='class'>,
#         <AxesSubplot:xlabel='pres', ylabel='class'>,
#         <AxesSubplot:xlabel='skin', ylabel='class'>,
#         <AxesSubplot:xlabel='test', ylabel='class'>,
#         <AxesSubplot:xlabel='mass', ylabel='class'>,
#         <AxesSubplot:xlabel='pedi', ylabel='class'>,
#         <AxesSubplot:xlabel='age', ylabel='class'>,
#         <AxesSubplot:xlabel='class', ylabel='class'>]], dtype=object)
